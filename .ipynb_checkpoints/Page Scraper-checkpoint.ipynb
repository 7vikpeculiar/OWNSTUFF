# %%
import requests

url = 'http://example.webscraping.com/'
response = requests.get(url)
html = response.content

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://web.archive.org/web/20121007172955/https://www.nga.gov/collection/anZ1.htm'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
print(soup.prettify())
# Out:
# --------------------------------------------------------------------------
# ImportError                              Traceback (most recent call last)
# <ipython-input-2-f915278181ea> in <module>()
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup
#       3
#       4 url = 'https://web.archive.org/web/20121007172955/https://www.nga.gov/collection/anZ1.htm'
#       5 response = requests.get(url)
#
# ImportError: No module named bs4

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://developers.google.com/open-source/gsoc/timeline'
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')
soup_tr = soup.find_all("tr")
print(soup_tr.find("td"))
# Out:
# --------------------------------------------------------------------------
# ImportError                              Traceback (most recent call last)
# <ipython-input-3-70f15a518719> in <module>()
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup
#       3
#       4 url = 'https://developers.google.com/open-source/gsoc/timeline'
#       5 page = requests.get(url)
#
# ImportError: No module named bs4

# %%
from dateparser.search import search_dates
# search_dates("The client arrived to the office for the first time in March 3rd, 2004 and got serviced, after a couple of months, on May 6th 2004, the customer returned indicating a defect on the part")
# search_dates(soup)

# %%
txt = soup.findAll(text=True)
txt_arr = []
for ele in txt:
    if(len(ele) < 1):
        continue
    txt_arr.append(search_dates(ele))

# %%
html = open(url).read()
html = ModifyHTML(html, "html5lib") #BeautifulSoup.
html.shift_links() #rewrite links as in requirements, above.
html.remove_images() #remove images as in requirements.
html = html.raw() #back to string.
 
# convert HTML to text.
h2t = HTMLToText()
plain = h2t.text(html, is_raw=True)
print(plain)
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-1-1133e648f366> in <module>()
# ----> 1 html = open(url).read()
#       2 html = ModifyHTML(html, "html5lib") #BeautifulSoup.
#       3 html.shift_links() #rewrite links as in requirements, above.
#       4 html.remove_images() #remove images as in requirements.
#       5 html = html.raw() #back to string.
#
# NameError: name 'url' is not defined

# %%
new_arr = []
for ele in txt_arr:
    if len(ele[0][0].split(" ")) > 1:
        new_arr.append(ele)
for ele in new_arr:
    if new_arr[0][0] in
# Out:
# ['\n',
#  'html',
#  'var a=window.devsite||{};window.devsite=a;a.readyCallbacks=[];window.devsite.readyCallbacks=a.readyCallbacks;a.ready=function(b){a.readyCallbacks.push(b)};window.devsite.ready=a.ready;\n',
#  "\n    var ___gcfg = ___gcfg || {};\n    ___gcfg.lang = 'en';\n  ",
#  'Google Summer of Code 2019 Timeline \xa0|\xa0 Google Summer of Code\n      \xa0|\xa0 Google Developers',
#  '\n    \n    \n      \n        Google Summer of Code\n      \n    \n    \n    ',
#  'All Products',
#  '\n  \n  Sign in\n',
#  '\n          Home\n        ',
#  '\n          Resources\n        ',
#  '\n          History\n        ',
#  '\n          Rules\n        ',
#  "\n    if (window.jQuery) {\n      $(document).ready(function() {\n        if (window.devsite && window.devsite.search) {\n          \n          window.devsite.search.init('en')\n        }\n      });\n    }\n  ",
#  '\n      var dataLayer = [{"freeTrialEligibleUser": "False", "userCountry": "IN", "language": {"requested": "en", "served": "en"}, "projectName": "Google Summer of Code", "scriptsafe": null, "signedIn": "False", "internalUser": "False"}];\n    ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n          Home\n        ',
#  '\n',
#  '\n',
#  '\n',
#  '\n          Resources\n        ',
#  '\n',
#  '\n',
#  '\n',
#  '\n          History\n        ',
#  '\n',
#  '\n',
#  '\n',
#  '\n          Rules\n        ',
#  '\n',
#  '\n',
#  '\n',
#  '\n        All Products\n      ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'FAQ',
#  'Videos',
#  'Glossary',
#  'Guides',
#  'Mailing Lists',
#  'Marketing',
#  'Resources',
#  'Roles and Responsibilities',
#  'Timeline',
#  'Contact Us',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  "\n  $(document).ready(function() {\n    devsite.ratings.init(\n      document.querySelectorAll('#devsite-feedback-project'), false\n      \n    );\n  });\n",
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n    \n    \n      Products\n    \n    \n    ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n    \n    \n      Open Source Programs Office\n    \n    \n    ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n    \n    \n      Google Summer of Code\n    \n    \n    ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n    \n    \n      Resources\n    \n    \n    ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n    Google Summer of Code 2019 Timeline\n  ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Date',
#  '\n',
#  'Event',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '2018',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'November 13',
#  '\n',
#  'Program announced',
#  '\n',
#  '\n',
#  '\n',
#  '2019',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'January 15 20:00 UTC',
#  '\n',
#  'Mentoring organizations can begin submitting applications to Google',
#  '\n',
#  '\n',
#  '\n',
#  'February 6 20:00 UTC',
#  '\n',
#  'Mentoring organization application deadline',
#  '\n',
#  '\n',
#  '\n',
#  'February 6 - February 25',
#  '\n',
#  'Google program administrators review organization applications',
#  '\n',
#  '\n',
#  '\n',
#  'February 26 12:00 UTC',
#  '\n',
#  'List of accepted mentoring organizations published',
#  '\n',
#  '\n',
#  '\n',
#  'February 26 - March 25',
#  '\n',
#  'Potential student participants discuss application ideas with mentoring organizations',
#  '\n',
#  '\n',
#  '\n',
#  'March 25 18:00 UTC',
#  '\n',
#  'Student application period begins',
#  '\n',
#  '\n',
#  '\n',
#  'April 9 18:00 UTC',
#  '\n',
#  'Student application deadline',
#  '\n',
#  '\n',
#  '\n',
#  'May 6 18:00 UTC',
#  '\n',
#  'Accepted student proposals announced',
#  '\n',
#  '\n',
#  '\n',
#  'Community Bonding Period',
#  '\n',
#  'Students get to know mentors, read documentation, get up to speed to begin working on their projects',
#  '\n',
#  '\n',
#  '\n',
#  'May 27',
#  '\n',
#  'Coding officially begins!',
#  '\n',
#  '\n',
#  '\n',
#  'June 24 18:00 UTC',
#  '\n',
#  'Mentors and students can begin submitting Phase 1 evaluations',
#  '\n',
#  '\n',
#  '\n',
#  'June 28 18:00 UTC',
#  '\n',
#  'Phase 1 Evaluation deadline',
#  '\n',
#  '\n',
#  '\n',
#  'Work Period',
#  '\n',
#  'Students work on their project with guidance from Mentors',
#  '\n',
#  '\n',
#  '\n',
#  'July 22 18:00 UTC',
#  '\n',
#  'Mentors and students can begin submitting Phase 2 evaluations',
#  '\n',
#  '\n',
#  '\n',
#  'July 26 18:00 UTC',
#  '\n',
#  'Phase 2 Evaluation deadline',
#  '\n',
#  '\n',
#  '\n',
#  'Work Period',
#  '\n',
#  'Students continue working on their project with guidance from Mentors',
#  '\n',
#  '\n',
#  '\n',
#  'August 19 - 26 18:00 UTC',
#  '\n',
#  'Final week: Students submit their final work product and their final mentor evaluation',
#  '\n',
#  '\n',
#  '\n',
#  'August 26 - Sept 2 18:00 UTC',
#  '\n',
#  'Mentors submit final student evaluations',
#  '\n',
#  '\n',
#  '\n',
#  'September 3',
#  '\n',
#  'Final results of Google Summer of Code 2019 announced',
#  '\n',
#  '\n',
#  '\n',
#  'October',
#  '\n',
#  'Mentor Summit at Google',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Except as otherwise noted, the content of this page is licensed under the ',
#  'Creative Commons Attribution 3.0 License',
#  '. For details, see our ',
#  'Site Policies',
#  '. Java is a registered trademark of Oracle and/or its affiliates.',
#  '\n',
#  '\n      \n      Last updated November 15, 2018.\n    ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n          \n          \n            Blog\n          \n        ',
#  '\n          \n          \n            Twitter\n          \n        ',
#  '\n          \n          \n            Facebook\n          \n        ',
#  'Connect',
#  '\n                Blog\n            ',
#  '\n                Facebook\n            ',
#  '\n                Medium\n            ',
#  '\n                Twitter\n            ',
#  '\n                YouTube\n            ',
#  'Programs',
#  '\n                Women Techmakers\n            ',
#  '\n                Agency Program\n            ',
#  '\n                GDG\n            ',
#  '\n                Google Developers Experts\n            ',
#  '\n                Startup Launchpad\n            ',
#  '\n                User Studies\n            ',
#  'Developer Consoles',
#  '\n                Google API Console\n            ',
#  '\n                Google Cloud Platform Console\n            ',
#  '\n                Google Play Console\n            ',
#  '\n                Firebase Console\n            ',
#  '\n                Actions on Google Console\n            ',
#  '\n                Cast SDK Developer Console\n            ',
#  '\n                Chrome Web Store Dashboard\n            ',
#  '\n                Android\n            ',
#  '\n                Chrome\n            ',
#  '\n                Firebase\n            ',
#  '\n                Google Cloud Platform\n            ',
#  '\n                All Products\n            ',
#  '\n            Bahasa Indonesia\n          ',
#  '\n            Deutsch\n          ',
#  '\n            English\n          ',
#  '\n            español\n          ',
#  '\n            français\n          ',
#  '\n            Português Brasileiro\n          ',
#  '\n            Русский\n          ',
#  '\n            日本語\n          ',
#  '\n            简体中文\n          ',
#  '\n            한국어\n          ',
#  'Terms\n         ',
#  'Privacy\n         ',
#  '\n        Sign up for the Google Developers newsletter\n      ',
#  '\n        \n        Subscribe\n      ',
#  '\n        (function($) {\n          \n          devsite.devsite.Init($, {\'ENABLE_BLOCKED_VIDEO_PLACEHOLDER\': 0, \'SITE_NAME\': \'devsite\', \'FULL_SITE_SEARCH_ENABLED\': 1, \'ENABLE_CLOUDTRACK\': 0, \'VTAGS_ENABLED\': 0, \'HISTORY_ENABLED\': 1, \'SIDEBAR_MINI_ENABLED\': 0, \'VERSION_HASH\': \'60f2f9b772\', \'SCRIPTSAFE_DOMAIN\': \'google-developers.appspot.com\', \'ENABLE_BLOCKED_LINK_TOOLTIP\': 0, \'ALLOWED_HOSTS\': [\'.android.com\', \'.appspot.com\', \'.gonglchuangl.net\', \'.google.cn\', \'.google.com\', \'.googleplex.com\', \'.tensorflow.org\'], \'BLOCK_RSS_FEEDS\': 0},\n                               \'[]\',\'en\',\n                               true, \'\',\n                               {"99a6bd77935176c43993ac6fe3e23dfc": true, "8de7a048f21618359bd37f5ce44be073": false, "098dafe57affddc137df300142652cfd": false, "8e03e230de0bd8a6fe173fdf172e8b3f": true, "cb025a64a50094835616312f4774a53d": true, "51470233c56fc1fde50f00b73c52b216": false, "d169d485cf24243a263783dbe42029b1": true, "700def1a83e356c06c0925afb05de4b0": false, "6749dcb526ce9bde6993550c7d928d24": true}, \'/open-source/gsoc/\',\n                               \'https://developers.google.com/\');\n        })(jQuery);\n\n        \n        devsite.localInit = function() {\n          \n        };\n\n      ',
#  "\n      $('.devsite-utility-footer-language-select').each(function() {\n        $(this).change(function(){$('.devsite-utility-footer-language').submit();});\n      });\n      ",
#  '\n']
