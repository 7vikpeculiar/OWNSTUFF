# %%
import re
import urllib.request
from bs4 import BeautifulSoup
 
html = urllib.request.urlopen('https://developers.google.com/open-source/gsoc/timeline')
soup = BeautifulSoup(html)
data = soup.findAll(text=True)
 
def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return False
    elif re.match('<!--.*-->', str(element.encode('utf-8'))):
        return False
    return True
 
result = filter(visible, data)
 
result = [ele.replace('\n','').strip() for ele in result]

# %%
def remove_values_from_list(the_list, val):
        while val in the_list:
            the_list.remove(val)
remove_values_from_list(result,'')

# %%
result
# Out:
# ['Google Summer of Code',
#  'Language',
#  'Bahasa Indonesia',
#  'Deutsch',
#  'English',
#  'español',
#  'français',
#  'Português Brasileiro',
#  'Русский',
#  '日本語',
#  '简体中文',
#  '한국어',
#  'All Products',
#  'Sign in',
#  'Home',
#  'Resources',
#  'History',
#  'Rules',
#  'Home',
#  'Resources',
#  'History',
#  'Rules',
#  'All Products',
#  'FAQ',
#  'Videos',
#  'Glossary',
#  'Guides',
#  'Mailing Lists',
#  'Marketing',
#  'Resources',
#  'Roles and Responsibilities',
#  'Timeline',
#  'Contact Us',
#  'Products',
#  'Open Source Programs Office',
#  'Google Summer of Code',
#  'Resources',
#  'Google Summer of Code 2019 Timeline',
#  'Date',
#  'Event',
#  '2018',
#  'November 13',
#  'Program announced',
#  '2019',
#  'January 15 20:00 UTC',
#  'Mentoring organizations can begin submitting applications to Google',
#  'February 6 20:00 UTC',
#  'Mentoring organization application deadline',
#  'February 6 - February 25',
# ...

# %%
from dateparser.search import search_dates
output = [search_dates(ele) for ele in result]
# search_dates()
# search_dates(soup)

# %%
output
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  [('2019', datetime.datetime(2019, 5, 15, 0, 0))],
#  None,
#  None,
#  [('2018', datetime.datetime(2018, 5, 15, 0, 0))],
#  [('November 13', datetime.datetime(2019, 11, 13, 0, 0))],
#  None,
#  [('2019', datetime.datetime(2019, 5, 15, 0, 0))],
#  [('January 15 20:00 UTC',
#    datetime.datetime(2019, 1, 15, 20, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  None,
#  [('February 6 20:00 UTC',
#    datetime.datetime(2019, 2, 6, 20, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  None,
#  [('February 6', datetime.datetime(2019, 2, 6, 0, 0)),
#   ('February 25', datetime.datetime(2019, 2, 25, 0, 0))],
#  None,
#  [('February 26 12:00 UTC',
# ...

# %%
cleaned_output = []
for ele in output:
    if ele == None:
        continue
    elif(len(ele[0][0])) <= 4:
        continue
    elif ' ' not in ele[0][0]:
        continue
    cleaned_output.append(ele)
cleaned_output
# Out:
# [[('November 13', datetime.datetime(2019, 11, 13, 0, 0))],
#  [('January 15 20:00 UTC',
#    datetime.datetime(2019, 1, 15, 20, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  [('February 6 20:00 UTC',
#    datetime.datetime(2019, 2, 6, 20, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  [('February 6', datetime.datetime(2019, 2, 6, 0, 0)),
#   ('February 25', datetime.datetime(2019, 2, 25, 0, 0))],
#  [('February 26 12:00 UTC',
#    datetime.datetime(2019, 2, 26, 12, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  [('February 26', datetime.datetime(2019, 2, 26, 0, 0)),
#   ('March 25', datetime.datetime(2019, 3, 25, 0, 0))],
#  [('March 25 18:00 UTC',
#    datetime.datetime(2019, 3, 25, 18, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  [('April 9 18:00 UTC',
#    datetime.datetime(2019, 4, 9, 18, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  [('May 6 18:00 UTC',
#    datetime.datetime(2019, 5, 6, 18, 0, tzinfo=<StaticTzInfo 'UTC'>))],
#  [('May 27', datetime.datetime(2019, 5, 27, 0, 0))],
#  [('June 24 18:00 UTC',
# ...
